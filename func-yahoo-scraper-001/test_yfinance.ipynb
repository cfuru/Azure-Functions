# %%
import yfinance as yf
import pandas as pd

pd.options.display.max_rows = 999

# %%
from yahooquery import Ticker

nvda = Ticker('nvda')
nvda.income_statement()

# %%
nvda.info
# Out:
# {'address1': '2788 San Tomas Expressway',
#  'city': 'Santa Clara',
#  'state': 'CA',
#  'zip': '95051',
#  'country': 'United States',
#  'phone': '408 486 2000',
#  'website': 'https://www.nvidia.com',
#  'industry': 'Semiconductors',
#  'industryDisp': 'Semiconductors',
#  'sector': 'Technology',
# ...

# %%
pd.DataFrame.from_dict(nvda.info, orient = "index")
# Out:
#                                                                               0
# address1                                              2788 San Tomas Expressway
# city                                                                Santa Clara
# state                                                                        CA
# zip                                                                       95051
# country                                                           United States
# phone                                                              408 486 2000
# website                                                  https://www.nvidia.com
# industry                                                         Semiconductors
# industryDisp                                                     Semiconductors
# sector                                                               Technology
# longBusinessSummary           NVIDIA Corporation provides graphics, and comp...
# ...

# %%
pd.DataFrame.from_dict(nvda.news[0], orient = "index")
# Out:
#                                                                      0
# uuid                              e2dbe1f5-c847-44c1-9a30-4e8ff875d0e2
# title                Jobs report, AI hype in focus after debt ceili...
# publisher                                                Yahoo Finance
# link                 https://finance.yahoo.com/news/jobs-report-ai-...
# providerPublishTime                                         1685289653
# type                                                             STORY
# thumbnail            {'resolutions': [{'url': 'https://s.yimg.com/u...
# relatedTickers                    [AI, ^GSPC, MRVL, ^IXIC, ^DJI, NVDA]
